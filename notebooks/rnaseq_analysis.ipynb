# %%
import pandas as pd

counts = pd.read_csv("../data/GSE60450_Lactation-GenewiseCounts.txt", sep="\t")

counts.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 counts = pd.read_csv("../data/GSE60450_Lactation-GenewiseCounts.txt", sep="\t")
#       5 counts.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

counts = pd.read_csv("../data/GSE60450_Lactation-GenewiseCounts.txt", sep="\t")

counts.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 counts = pd.read_csv("../data/GSE60450_Lactation-GenewiseCounts.txt", sep="\t")
#       5 counts.head()
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 8.1 MB/s  0:00:01m0:00:0100:01m
# Using cached numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...

# %%
import pandas as pd

counts = pd.read_csv("../data/GSE60450_Lactation-GenewiseCounts.txt", sep="\t")

counts.head()
# Out:
#    EntrezGeneID  Length  MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1  \
# 0        497097    3634                                438
# 1     100503874    3259                                  1
# 2     100038431    1634                                  0
# 3         19888    9747                                  1
# 4         20671    3130                                106
#
#    MCL1-DH_BC2CTUACXX_CAGATC_L002_R1  MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1  \
# 0                                300                                 65
# 1                                  0                                  1
# 2                                  0                                  0
# 3                                  1                                  0
# 4                                182                                 82
#
#    MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1  MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1  \
# 0                                237                                354
# ...

# %%
counts.shape
# Out:
# (27179, 14)

# %%
counts.columns
# Out:
# Index(['EntrezGeneID', 'Length', 'MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1',
#        'MCL1-DH_BC2CTUACXX_CAGATC_L002_R1',
#        'MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1',
#        'MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1',
#        'MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1',
#        'MCL1-DL_BC2CTUACXX_ATCACG_L002_R1',
#        'MCL1-LA_BC2CTUACXX_GATCAG_L001_R1',
#        'MCL1-LB_BC2CTUACXX_TGACCA_L001_R1',
#        'MCL1-LC_BC2CTUACXX_GCCAAT_L001_R1',
#        'MCL1-LD_BC2CTUACXX_GGCTAC_L001_R1',
#        'MCL1-LE_BC2CTUACXX_TAGCTT_L001_R1',
#        'MCL1-LF_BC2CTUACXX_CTTGTA_L001_R1'],
#       dtype='object')

# %%
counts.head(10)
# Out:
#    EntrezGeneID  Length  MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1  \
# 0        497097    3634                                438
# 1     100503874    3259                                  1
# 2     100038431    1634                                  0
# 3         19888    9747                                  1
# 4         20671    3130                                106
# 5         27395    4203                                309
# 6         18777    2433                                652
# 7     100503730     799                                  0
# 8         21399    2847                               1604
# 9         58175    2241                                  4
#
#    MCL1-DH_BC2CTUACXX_CAGATC_L002_R1  MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1  \
# 0                                300                                 65
# 1                                  0                                  1
# 2                                  0                                  0
# ...

# %%
counts.shape
# Out:
# (27179, 14)

# %%
count_matrix = counts.drop(columns=["EntrezGeneID", "Length"])

count_matrix.head()
# Out:
#    MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1  MCL1-DH_BC2CTUACXX_CAGATC_L002_R1  \
# 0                                438                                300
# 1                                  1                                  0
# 2                                  0                                  0
# 3                                  1                                  1
# 4                                106                                182
#
#    MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1  MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1  \
# 0                                 65                                237
# 1                                  1                                  1
# 2                                  0                                  0
# 3                                  0                                  0
# 4                                 82                                105
#
#    MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1  MCL1-DL_BC2CTUACXX_ATCACG_L002_R1  \
# ...

# %%
count_matrix.shape
# Out:
# (27179, 12)

# %%
conditions = ["pregnancy"]*6 + ["lactation"]*6
conditions
# Out:
# ['pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'lactation',
#  'lactation',
#  'lactation',
#  'lactation',
#  'lactation',
#  'lactation']

# %%
# !pip install matplotlib seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 9.1 MB/s  0:00:00m eta 0:00:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 8.6 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.9 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 8.6 MB/s  0:00:00 eta 0:00:01m
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [seaborn]m7/8 [seaborn]ib]
# ...

# %%
count_matrix.shape
# Out:
# (27179, 12)

# %%
count_matrix = counts.iloc[:, 2:]

count_matrix.head()
# Out:
#    MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1  MCL1-DH_BC2CTUACXX_CAGATC_L002_R1  \
# 0                                438                                300
# 1                                  1                                  0
# 2                                  0                                  0
# 3                                  1                                  1
# 4                                106                                182
#
#    MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1  MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1  \
# 0                                 65                                237
# 1                                  1                                  1
# 2                                  0                                  0
# 3                                  0                                  0
# 4                                 82                                105
#
#    MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1  MCL1-DL_BC2CTUACXX_ATCACG_L002_R1  \
# ...

# %%
count_matrix.shape
# Out:
# (27179, 12)

# %%
count_matrix.columns
# Out:
# Index(['MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1',
#        'MCL1-DH_BC2CTUACXX_CAGATC_L002_R1',
#        'MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1',
#        'MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1',
#        'MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1',
#        'MCL1-DL_BC2CTUACXX_ATCACG_L002_R1',
#        'MCL1-LA_BC2CTUACXX_GATCAG_L001_R1',
#        'MCL1-LB_BC2CTUACXX_TGACCA_L001_R1',
#        'MCL1-LC_BC2CTUACXX_GCCAAT_L001_R1',
#        'MCL1-LD_BC2CTUACXX_GGCTAC_L001_R1',
#        'MCL1-LE_BC2CTUACXX_TAGCTT_L001_R1',
#        'MCL1-LF_BC2CTUACXX_CTTGTA_L001_R1'],
#       dtype='object')

# %%
samples = count_matrix.columns

conditions = ["pregnancy" if "-D" in s else "lactation" for s in samples]

conditions
# Out:
# ['pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'pregnancy',
#  'lactation',
#  'lactation',
#  'lactation',
#  'lactation',
#  'lactation',
#  'lactation']

# %%
metadata = pd.DataFrame({
    "sample": samples,
    "condition": conditions
})

metadata
# Out:
#                                sample  condition
# 0   MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1  pregnancy
# 1   MCL1-DH_BC2CTUACXX_CAGATC_L002_R1  pregnancy
# 2   MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1  pregnancy
# 3   MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1  pregnancy
# 4   MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1  pregnancy
# 5   MCL1-DL_BC2CTUACXX_ATCACG_L002_R1  pregnancy
# 6   MCL1-LA_BC2CTUACXX_GATCAG_L001_R1  lactation
# 7   MCL1-LB_BC2CTUACXX_TGACCA_L001_R1  lactation
# 8   MCL1-LC_BC2CTUACXX_GCCAAT_L001_R1  lactation
# 9   MCL1-LD_BC2CTUACXX_GGCTAC_L001_R1  lactation
# 10  MCL1-LE_BC2CTUACXX_TAGCTT_L001_R1  lactation
# 11  MCL1-LF_BC2CTUACXX_CTTGTA_L001_R1  lactation

# %%
samples = count_matrix.columns

conditions = ["pregnancy" if "-D" in s else "lactation" for s in samples]

import pandas as pd

metadata = pd.DataFrame({
    "sample": samples,
    "condition": conditions
})

metadata
# Out:
#                                sample  condition
# 0   MCL1-DG_BC2CTUACXX_ACTTGA_L002_R1  pregnancy
# 1   MCL1-DH_BC2CTUACXX_CAGATC_L002_R1  pregnancy
# 2   MCL1-DI_BC2CTUACXX_ACAGTG_L002_R1  pregnancy
# 3   MCL1-DJ_BC2CTUACXX_CGATGT_L002_R1  pregnancy
# 4   MCL1-DK_BC2CTUACXX_TTAGGC_L002_R1  pregnancy
# 5   MCL1-DL_BC2CTUACXX_ATCACG_L002_R1  pregnancy
# 6   MCL1-LA_BC2CTUACXX_GATCAG_L001_R1  lactation
# 7   MCL1-LB_BC2CTUACXX_TGACCA_L001_R1  lactation
# 8   MCL1-LC_BC2CTUACXX_GCCAAT_L001_R1  lactation
# 9   MCL1-LD_BC2CTUACXX_GGCTAC_L001_R1  lactation
# 10  MCL1-LE_BC2CTUACXX_TAGCTT_L001_R1  lactation
# 11  MCL1-LF_BC2CTUACXX_CTTGTA_L001_R1  lactation

# %%
count_matrix.to_csv("../data/count_matrix.csv")
metadata.to_csv("../data/metadata.csv", index=False)

# %%
ls ~/rnaseq_project/data
# Out:
# GSE60450_Lactation-GenewiseCounts.txt*  count_matrix.csv  metadata.csv
